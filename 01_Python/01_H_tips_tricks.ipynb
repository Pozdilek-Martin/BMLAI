# %% [markdown]
# # Jazykové idiomy
# V Pythonu existují doporučené způsoby zápisu, které jsou přehledné, stručné a efektivní. Tomu říkáme **Pythonic**.
#
# Opakem je Unpythonic – zápis, který je neefektivní, nečitelý nebo připomíná jiné jazyky (např. C, Java).
#
# Hlavní myšlenky pythonu lze vypsat importem this

# %%
import this

# %% [markdown]
# ## Procházení seznamem

# %% [markdown]
# Ošklivý způsob

# %%
i = 0
items=(1, 2, 3)
while i < len(items):
    print (items[i])
    i +=1

# %% [markdown]
# Hezký způsob

# %%
for item in items:
    print (item)

# %% [markdown]
# ## Kontrola seznamu

# %% [markdown]
# Ošklivý způsob

# %%
if len(items) != 0:
    print("The list is not empty")

# %% [markdown]
# Hezký způsob

# %%
if items:
    print("The list is not empty")

# %% [markdown]
# # Podmíněné přiřazení hodnoty

# %% [markdown]
# Ošklivý způsob

# %%
x = 2
if x > 0:
    char = "+"
else:
    char = "-"

# %% [markdown]
# Hezký způsob

# %%
char = "+" if x > 0 else "-"

# %% [markdown]
# # Anonymní, lambda funkce

# %% [markdown]
# Ošklivý způsob

# %%
def double(x):
    return x * 2

double(5)

# %% [markdown]
# Hezký způsob

# %%
double_lambda = lambda x: x * 2
double_lambda(20)

# %% [markdown]
# # list/set/dict comprehension
# * Lze  provést matematickou operaci nad listem
# * Pro každé x ze seznamu, pokud je x dělitelné 2, vypočítej jeho druhou mocninu

# %%
numbers = [1, 2, 3, 4, 5]
squares = [x ** 2 for x in numbers if x % 2 == 0]
squares

# %% [markdown]
# # Chain comparision

# %% [markdown]
# Ošklivý způsob

# %%
x=4
if 1 < x and x < 5:
    print ("x is between 1 and 5")

# %% [markdown]
# Hezký způsob

# %%
x=4
if 1 < x < 5:
    print ("x is between 1 and 5")

# %% [markdown]
# # Prohození proměnných

# %% [markdown]
# Ošklivý způsob

# %%
a, b = 1, 2

tmp = a
a = b
b = tmp
print(a, b)

# %% [markdown]
# Hezký způsob

# %%
a, b = 1, 2
a, b = b, a
print(a, b)

# %% [markdown]
# # zip() — procházení dvou seznamů najednou
#
# `zip()` spojí dva (nebo více) seznamů do dvojic a umožní je procházet najednou.

# %% [markdown]
# Ošklivý způsob

# %%
names = ["Alice", "Bob", "Carol"]
scores = [95, 82, 78]

for i in range(len(names)):
    print(names[i], scores[i])

# %% [markdown]
# Hezký způsob

# %%
names = ["Alice", "Bob", "Carol"]
scores = [95, 82, 78]

for name, score in zip(names, scores):
    print(f"{name}: {score}")

# %% [markdown]
# # any() a all()
#
# `any()` vrátí `True`, pokud alespoň jeden prvek splňuje podmínku.
# `all()` vrátí `True`, pokud ji splňují všechny prvky.

# %% [markdown]
# Ošklivý způsob

# %%
values = [0, 1, 2, 3]

found = False
for v in values:
    if v > 2:
        found = True
        break

print(found)

# %% [markdown]
# Hezký způsob

# %%
values = [0, 1, 2, 3]

found = any(v > 2 for v in values)
all_positive = all(v >= 0 for v in values)

print(all_positive)

# %% [markdown]
# # dict.get() — bezpečný přístup ke slovníku
#
# Přístup přes `d[key]` vyvolá `KeyError`, pokud klíč neexistuje. `d.get(key, default)` místo toho vrátí výchozí hodnotu.

# %% [markdown]
# Ošklivý způsob

# %%
config = {"host": "localhost", "port": 8080}

# ugly – raises KeyError if key is missing
timeout = config["timeout"]

# %% [markdown]
# Hezký způsob

# %%
config = {"host": "localhost", "port": 8080}

timeout = config.get("timeout", 30)   # returns 30 if key doesn't exist
host    = config.get("host", "127.0.0.1")

print(timeout)  # 30
print(host)     # localhost

# %% [markdown]
# # enumerate() se start=
#
# `enumerate()` přidá počítadlo k iteraci. Parametr `start=` určí počáteční hodnotu (výchozí je 0).

# %% [markdown]
# Ošklivý způsob

# %%
items = ["apple", "banana", "cherry"]

for i in range(len(items)):
    print(f"{i+1}. {items[i]}")

# %% [markdown]
# Hezký způsob

# %%
items = ["apple", "banana", "cherry"]

for i, item in enumerate(items, start=1):
    print(f"{i}. {item}")

# %% [markdown]
# # Walrus operátor :=
#
# **Walrus operátor** (`:=`) přiřadí hodnotu proměnné a zároveň ji vrátí jako výsledek výrazu. Typické použití je ve `while` cyklu — přiřazení a testování podmínky v jednom kroku.

# %% [markdown]
# Ošklivý způsob

# %%
data = b"hello world from a long stream"
i = 0
block_size = 8
blocks = []
while True:
    block = data[i:i+block_size]
    if not block:
        break
    blocks.append(block)
    i += block_size
print(blocks)

# %% [markdown]
# Hezký způsob

# %%
data = b"hello world from a long stream"

# Beautiful – walrus assigns a block and checks at the same time to see if it is empty
import io
f = io.BytesIO(data)
blocks = []
while block := f.read(8):
    blocks.append(block)
print(blocks)

# %% [markdown]
# # Cache výsledků funkcí (memoizace)
# Někdy funkce volá sama sebe nebo zpracovává náročné výpočty.
#
# Abychom nezpracovávali stejné vstupy vícekrát, můžeme výsledky uložit do cache.

# %%
def fib(n: int) -> int:
    if n <= 1:
        return n
    else:
        return fib (n - 1) + fib (n - 2)

# %%
for i in range (0, 40):
    print (f'{i}: {fib(i)}')

# %% [markdown]
# Python má vestavěný dekorátor @functools.lru_cache:
#
# LRU = Least Recently Used (odstraní nejméně používané položky, pokud cache dosáhne limitu)
#
# Umožňuje automaticky ukládat výsledky podle parametrů funkce.

# %%
from functools import lru_cache
@lru_cache
def fib(n: int) -> int:
    if n <= 1:
        return n
    else:
        return fib (n - 1) + fib (n - 2)

# %%
for i in range (0, 40):
    print (f'{i}: {fib(i)}')

# %% [markdown]
# # Funkce help()
# Vypisuje syntaxe python příkazu.

# %%
help(print)

# %% [markdown]
# Pokud budete používat u funkcí dokumentační string, tak si nápovědu můžete vypisovat i k vlastním funkcím.

# %%
def my_func(a : int, b:int )-> int:
    """ Adding two numbers
    a: int
    b: int
    
    return int
    """
    return (a+b)

# %%
my_func(1, 3)

# %%
help(my_func)
