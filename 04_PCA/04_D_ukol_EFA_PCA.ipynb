# %% [markdown]
# # Analýza hlavních komponent
#
# ## Úkol
# V datasetu Portland Housing Prices/Sales Jul 2020 - Jul 2021 zjistěte, jestli je zde problém multikolinearity.
#
# - Udělejte VIF
# - Udělejte EFA
# - Udělejte  PCA
# - Dobrovolně L1, L2, Elastic Net
# - Modely porovnejte a vyberte nejlepší

# %% [markdown]
# # Načtení dat

# %%
import pandas as pd

# %%
data = pd.read_csv ("..\\dataset\\portland_filtered.csv",  sep=';')

# %% [markdown]
# # Analýza
# - zobrazte data
# - vyřešte NaN hodnoty
# - zobrazte základní statistiky dat
# - zobrazte korelační matici

# %% [markdown]
# # Příprava dat
# - vyberte X proměnné bathrooms', 'bedrooms', 'livingArea','age','price'
# - proměnné standardizujte

# %% [markdown]
# # Zobrazte VIF pro každou proměnnou

# %% [markdown]
# # EFA
# - Proveďte EFA
# - Vytvořte model z EFA

# %% [markdown]
# # PCA
# - Proveďte PCA
# - Vytvořte model z PCA

# %% [markdown]
# # Lineární model s L1 a L2
# - Lineární model s L1 a L2

# %% [markdown]
# # Výběr modelu
# Který model byste zvolili a proč?
